# %% [markdown]
# # Segment satellite images
#
# The purpose of this notebook is to show how SAM (Segment anything) model (https://github.com/facebookresearch/segment-anything) can be used to segment satellite images.

# %%
# import libraries

# %%
import torch
import os
import cv2
import numpy as np
from segment_anything import sam_model_registry, SamPredictor, SamAutomaticMaskGenerator
import matplotlib.pyplot as plt
import matplotlib

# %%
# for notebook plotting

# %%
# %matplotlib inline

# %%
# checkpoint for the model cqn be downloaded from https://github.com/facebookresearch/segment-anything#model-checkpoints

# %%
# define model, checkpoint and input image
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
MODEL_TYPE = "vit_h"
CHECKPOINT_ABS_PATH = r"checkpoint\sam_vit_h_4b8939.pth"
IMAGE_PATH = r"images\flower_small.jpg"

# %%
# load model
sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_ABS_PATH)
sam.to(device=DEVICE)

mask_generator = SamAutomaticMaskGenerator(sam)

image_bgr = cv2.imread(IMAGE_PATH)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# %%
# disp input image
plt.imshow(image_rgb)

# %%
# generate segmentation mask, this step can be slow
masks = mask_generator.generate(image_rgb)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
#available fields for each mask
masks[0].keys()
# Out:
# dict_keys(['segmentation', 'area', 'bbox', 'predicted_iou', 'point_coords', 'stability_score', 'crop_box'])

# %%
# helper function to show masks
def show_anns(anns):
    if len(anns) == 0:
        return
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    ax = plt.gca()
    ax.set_autoscale_on(False)

    # Note. dim 4 is for alpha channel
    img = np.ones((sorted_anns[0]['segmentation'].shape[0], sorted_anns[0]['segmentation'].shape[1], 4))
    img[:,:,3] = 0
    for ann in sorted_anns:
        m = ann['segmentation']
        color_mask = np.concatenate([np.random.random(3), [0.35]])
        img[m] = color_mask
    ax.imshow(img)
    
plt.imshow(image_rgb)
ax = plt.gca()
show_anns(masks)
plt.axis("off")
plt.show()

# %%
# show all segmented masks

# %%
# number of features detected
print("Number of masks:", len(masks))
# Out:
# Number of masks: 113

# %%
# let's displqy only some of them
NB_MASKS = 3 # number of rows
fig, axs = plt.subplots(NB_MASKS, 3, figsize=(10, 15), gridspec_kw={'wspace': 0.3, 'hspace': 0.5})

count = 0
for ax in axs.flat:
    ax.imshow(masks[count]['segmentation'], aspect='auto')
    count += 1

# %% [markdown]
# # Bounding box

# %% [markdown]
# To draw the bounding box we will use a widget

# %%
#!pip install jupyter_bbox_widget

# %%
from jupyter_bbox_widget import BBoxWidget

# %%
widget = BBoxWidget(
    image=IMAGE_PATH,
    classes=['flower', 'bee'],
)
widget
# Out:
# BBoxWidget(classes=['flower', 'bee'], colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b'…

# %%
widget.bboxes
# Out:
# [{'x': 292, 'y': 193, 'width': 44, 'height': 40, 'label': 'bee'},
#  {'x': 172, 'y': 44, 'width': 242, 'height': 271, 'label': 'flower'}]

# %%
box = widget.bboxes[1]
box = np.array([box['x'], box['y'], box['x'] + box['width'], box['y'] + box['height']])

# %%
predictor = SamPredictor(sam)
predictor.set_image(image_rgb)

# %%
masks, scores, logits = predictor.predict(box=box, multimask_output=True)

# %%
def plot_mask(masks):
    masks = np.moveaxis(masks, [0, 1, 2], [2, 0, 1])
    masks = masks[:,:,0]
    img = np.ones((masks.shape[0], masks.shape[1], 4))
    img[:,:,3] = 0
    color_mask = matplotlib.colors.to_rgba('blue')
    img[masks] = color_mask
    ax = plt.gca()
    ax.imshow(img)

# %%
plt.imshow(image_rgb)
plot_mask(masks)
plt.axis("off")
plt.show()

# %%
box = widget.bboxes[0]
box = np.array([box['x'], box['y'], box['x'] + box['width'], box['y'] + box['height']])

# %%
masks, scores, logits = predictor.predict(box=box, multimask_output=True)

# %%
plt.imshow(image_rgb)
plot_mask(masks)
plt.axis("off")
plt.show()
